# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 607

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&unit"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gaigeturi
# Processing Record 1 of Set 1 | waitangi
# Processing Record 1 of Set 1 | cabedelo
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 1 of Set 1 | ribeira grande
# Processing Record 1 of Set 1 | tayoltita
# Processing Record 1 of Set 1 | artesia
# Processing Record 1 of Set 1 | puerto natales
# Processing Record 1 of Set 1 | enewetak
# Processing Record 1 of Set 1 | albany
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 1 of Set 1 | alice springs
# Processing Record 1 of Set 1 | fort st. john
# Processing Record 1 of Set 1 | haiku-pauwela
# Processing Record 1 of Set 1 | flin flon
# Processing Record 1 of Set 1 | al hazm
# Processing Record 1 of Set 1 | bethel
# Processing Record 1 of Set 1 | port lincoln
# Processing Record 1 of Set 1 | isafjordur
# Processing Record 1 of Set 1 | mukah
# Processing Record 1 of Set 1 | sao pedro da aldeia
# Processing Record 1 of Set 1 | 'izbat al burj
# Processing Record 1 of Set 1 | taiohae
# Processing Record 1 of Set 1 | kodiak
# Processing Record 1 of Set 1 | margaret river
# Processing Record 1 of Set 1 | afaahiti
# Processing Record 1 of Set 1 | fort mcmurray
# Processing Record 1 of Set 1 | grytviken
# Processing Record 1 of Set 1 | sitka
# Processing Record 1 of Set 1 | atafu village
# Processing Record 1 of Set 1 | sola
# Processing Record 1 of Set 1 | kapa'a
# Processing Record 1 of Set 1 | al ghayzah
# Processing Record 1 of Set 1 | san patricio
# Processing Record 1 of Set 1 | sinabang
# Processing Record 1 of Set 1 | stanley
# Processing Record 1 of Set 1 | kismayo
# Processing Record 1 of Set 1 | tura
# Processing Record 1 of Set 1 | college
# Processing Record 1 of Set 1 | ciudad constitucion
# Processing Record 1 of Set 1 | anadyr
# Processing Record 1 of Set 1 | port saint john's
# Processing Record 1 of Set 1 | broken hill
# Processing Record 1 of Set 1 | masterton
# Processing Record 1 of Set 1 | zaozersk
# Processing Record 1 of Set 1 | chernomorskoye
# Processing Record 1 of Set 1 | jamestown
# Processing Record 1 of Set 1 | ust-tsilma
# Processing Record 1 of Set 1 | fort bragg
# Processing Record 1 of Set 1 | lebu
# Processing Record 0 of Set 2 | rikaze
# Processing Record 0 of Set 2 | avarua
# Processing Record 0 of Set 2 | akrehamn
# Processing Record 0 of Set 2 | adamstown
# Processing Record 0 of Set 2 | yellowknife
# Processing Record 0 of Set 2 | longyearbyen
# Processing Record 0 of Set 2 | bush
# Processing Record 0 of Set 2 | new norfolk
# Processing Record 0 of Set 2 | remire-montjoly
# Processing Record 0 of Set 2 | port-aux-francais
# Processing Record 0 of Set 2 | edinburgh of the seven seas
# Processing Record 0 of Set 2 | swan hill
# Processing Record 0 of Set 2 | acarau
# Processing Record 0 of Set 2 | qaqortoq
# Processing Record 0 of Set 2 | devils lake
# Processing Record 0 of Set 2 | kiruna
# Processing Record 0 of Set 2 | bulayevo
# Processing Record 0 of Set 2 | bilibino
# Processing Record 0 of Set 2 | la sarre
# Processing Record 0 of Set 2 | zahedan
# Processing Record 0 of Set 2 | piti village
# Processing Record 0 of Set 2 | puerto ayora
# Processing Record 0 of Set 2 | iskateley
# Processing Record 0 of Set 2 | tolanaro
# Processing Record 0 of Set 2 | port alfred
# Processing Record 0 of Set 2 | udachny
# Processing Record 0 of Set 3 | polevskoy
# Processing Record 0 of Set 3 | hawaiian paradise park
# Processing Record 0 of Set 3 | hermanus
# Processing Record 0 of Set 3 | nantucket
# Processing Record 0 of Set 3 | kilosa
# Processing Record 0 of Set 4 | vilani
# Processing Record 0 of Set 4 | geraldton
# Processing Record 0 of Set 4 | papatowai
# Processing Record 0 of Set 4 | weno
# Processing Record 0 of Set 4 | setti fatma
# Processing Record 0 of Set 4 | bubaque
# Processing Record 0 of Set 4 | aasiaat
# Processing Record 0 of Set 4 | kuanda
# Processing Record 0 of Set 4 | sarangani
# Processing Record 0 of Set 4 | dalandzadgad
# Processing Record 0 of Set 4 | georgetown
# Processing Record 0 of Set 4 | micheweni
# Processing Record 0 of Set 4 | ulsteinvik
# Processing Record 0 of Set 4 | tsiombe
# Processing Record 0 of Set 4 | arkhangel'sk
# Processing Record 0 of Set 4 | shakawe
# Processing Record 0 of Set 4 | kuraymah
# Processing Record 0 of Set 4 | galveston
# Processing Record 0 of Set 4 | hue
# Processing Record 0 of Set 4 | badger
# Processing Record 0 of Set 4 | sao jose da coroa grande
# Processing Record 0 of Set 4 | vilyuysk
# Processing Record 0 of Set 4 | jinchang
# Processing Record 0 of Set 4 | greymouth
# Processing Record 0 of Set 4 | massawa
# Processing Record 0 of Set 4 | kashgar
# Processing Record 0 of Set 4 | porto novo
# Processing Record 0 of Set 4 | dubbo
# Processing Record 0 of Set 4 | kinzan
# Processing Record 0 of Set 4 | kailua-kona
# Processing Record 0 of Set 4 | yagry
# Processing Record 0 of Set 4 | vila velha
# Processing Record 0 of Set 4 | saipan
# Processing Record 0 of Set 4 | west island
# Processing Record 0 of Set 4 | tot'ma
# Processing Record 0 of Set 4 | bac kan
# Processing Record 0 of Set 4 | hami
# Processing Record 0 of Set 4 | alotau
# Processing Record 0 of Set 4 | ijuw
# Processing Record 0 of Set 4 | eyl
# Processing Record 0 of Set 4 | sisimiut
# Processing Record 0 of Set 4 | tiksi
# Processing Record 0 of Set 4 | quimili
# Processing Record 0 of Set 4 | along
# Processing Record 0 of Set 4 | dapchi
# Processing Record 0 of Set 4 | lazaro cardenas
# Processing Record 0 of Set 4 | iqaluit
# Processing Record 0 of Set 4 | pak phanang
# Processing Record 0 of Set 4 | aktau
# Processing Record 0 of Set 4 | manistee
# Processing Record 0 of Set 5 | mount pearl
# Processing Record 0 of Set 5 | senanga
# Processing Record 0 of Set 5 | olyokminsk
# Processing Record 0 of Set 5 | arraial do cabo
# Processing Record 0 of Set 5 | thompson
# Processing Record 0 of Set 5 | rio grande
# Processing Record 0 of Set 5 | bac lieu
# Processing Record 0 of Set 5 | columbia city
# Processing Record 0 of Set 5 | burang
# Processing Record 0 of Set 5 | marka
# Processing Record 0 of Set 5 | rocha
# Processing Record 0 of Set 5 | popondetta
# Processing Record 0 of Set 5 | demba
# Processing Record 0 of Set 5 | illizi
# Processing Record 0 of Set 5 | necochea
# Processing Record 0 of Set 5 | tambopata
# Processing Record 0 of Set 5 | pul-e khumri
# Processing Record 0 of Set 5 | n'zeto
# Processing Record 0 of Set 5 | wenchang
# Processing Record 0 of Set 5 | tocopilla
# Processing Record 0 of Set 5 | saudarkrokur
# Processing Record 0 of Set 5 | lata
# Processing Record 0 of Set 5 | laguna
# Processing Record 0 of Set 5 | effium
# Processing Record 0 of Set 5 | bel ombre
# Processing Record 0 of Set 5 | calama
# Processing Record 0 of Set 5 | vilyuchinsk
# Processing Record 0 of Set 5 | inhambane
# Processing Record 0 of Set 5 | saint-philippe
# Processing Record 0 of Set 5 | idfu
# Processing Record 0 of Set 5 | kill devil hills
# Processing Record 0 of Set 5 | cozumel
# Processing Record 0 of Set 5 | mount gambier
# Processing Record 0 of Set 5 | bismarck
# Processing Record 0 of Set 5 | saint-pierre
# Processing Record 0 of Set 5 | guerrero negro
# Processing Record 0 of Set 5 | igrim
# Processing Record 0 of Set 5 | murun-kuren
# Processing Record 0 of Set 5 | brannenburg
# Processing Record 0 of Set 5 | darchula
# Processing Record 0 of Set 5 | lubang
# Processing Record 0 of Set 5 | battenberg
# Processing Record 0 of Set 5 | takamaka
# Processing Record 0 of Set 5 | afif
# Processing Record 0 of Set 5 | beledweyne
# Processing Record 0 of Set 5 | san antonio de pale
# Processing Record 0 of Set 5 | cuenca
# Processing Record 0 of Set 5 | cromer
# Processing Record 0 of Set 5 | mahibadhoo
# Processing Record 0 of Set 5 | invercargill
# Processing Record 0 of Set 6 | caernarfon
# Processing Record 0 of Set 6 | mount isa
# Processing Record 0 of Set 6 | tangalle
# Processing Record 0 of Set 6 | aripuana
# Processing Record 0 of Set 6 | luderitz
# Processing Record 0 of Set 6 | vadso
# Processing Record 0 of Set 6 | ascension
# Processing Record 0 of Set 6 | santa rosa
# Processing Record 0 of Set 6 | viana
# Processing Record 0 of Set 6 | tabou
# Processing Record 0 of Set 6 | ancud
# Processing Record 0 of Set 6 | susuman
# Processing Record 0 of Set 6 | katsuura
# Processing Record 0 of Set 6 | giddings
# Processing Record 0 of Set 6 | nova vicosa
# Processing Record 0 of Set 6 | jobabo
# Processing Record 0 of Set 6 | naze
# Processing Record 0 of Set 6 | swift current
# Processing Record 0 of Set 6 | peterhead
# Processing Record 0 of Set 6 | gamba
# Processing Record 0 of Set 6 | malvan
# Processing Record 0 of Set 6 | uturoa
# Processing Record 0 of Set 6 | nefta
# Processing Record 0 of Set 6 | denison
# Processing Record 0 of Set 6 | mukalla
# Processing Record 0 of Set 6 | jakar
# Processing Record 0 of Set 6 | bereeda
# Processing Record 0 of Set 6 | port mathurin
# Processing Record 0 of Set 6 | ulety
# Processing Record 0 of Set 6 | ceeldheer
# Processing Record 0 of Set 6 | sao miguel do araguaia
# Processing Record 0 of Set 6 | inarajan village
# Processing Record 0 of Set 6 | regina
# Processing Record 0 of Set 6 | lospalos
# Processing Record 0 of Set 6 | ibra'
# Processing Record 0 of Set 6 | city of balikpapan
# Processing Record 0 of Set 6 | oriximina
# Processing Record 0 of Set 6 | bodo
# Processing Record 0 of Set 6 | saratamata
# Processing Record 0 of Set 6 | urucara
# Processing Record 0 of Set 6 | port shepstone
# Processing Record 0 of Set 6 | severo-yeniseyskiy
# Processing Record 0 of Set 6 | tateyama
# Processing Record 0 of Set 6 | bastia
# Processing Record 0 of Set 6 | san jeronimito
# Processing Record 0 of Set 6 | kozelets'
# Processing Record 0 of Set 6 | kyabram
# Processing Record 0 of Set 6 | kataragama
# Processing Record 0 of Set 6 | luwuk
# Processing Record 0 of Set 6 | revda
# Processing Record 0 of Set 7 | boyolangu
# Processing Record 0 of Set 7 | umm kaddadah
# Processing Record 0 of Set 7 | el calafate
# Processing Record 0 of Set 7 | east london
# Processing Record 0 of Set 7 | tegueste
# Processing Record 0 of Set 7 | kruisfontein
# Processing Record 0 of Set 7 | labytnangi
# Processing Record 0 of Set 7 | wolmaransstad
# Processing Record 0 of Set 7 | colonia
# Processing Record 0 of Set 7 | kingston
# Processing Record 0 of Set 7 | san luis de la loma
# Processing Record 0 of Set 7 | bandar lampung
# Processing Record 0 of Set 7 | ginir
# Processing Record 0 of Set 7 | juneau
# Processing Record 0 of Set 7 | ouani
# Processing Record 0 of Set 7 | mogocha
# Processing Record 0 of Set 7 | esquina
# Processing Record 0 of Set 7 | amga
# Processing Record 0 of Set 7 | la'ie
# Processing Record 0 of Set 7 | el nido
# Processing Record 0 of Set 7 | felidhoo
# Processing Record 0 of Set 7 | kushiro
# Processing Record 0 of Set 7 | polyarnyy
# Processing Record 0 of Set 7 | tazacorte
# Processing Record 0 of Set 7 | stavropol'
# Processing Record 0 of Set 7 | arkhara
# Processing Record 0 of Set 7 | klaksvik
# Processing Record 0 of Set 7 | tazovsky
# Processing Record 0 of Set 7 | nizhnyaya poyma
# Processing Record 0 of Set 7 | yen bai
# Processing Record 0 of Set 7 | cannonvale
# Processing Record 0 of Set 7 | urumqi
# Processing Record 0 of Set 7 | svetlyy
# Processing Record 0 of Set 7 | salinopolis
# Processing Record 0 of Set 7 | toga village
# Processing Record 0 of Set 7 | kiunga
# Processing Record 0 of Set 7 | hamilton
# Processing Record 0 of Set 7 | richards bay
# Processing Record 0 of Set 7 | pemba
# Processing Record 0 of Set 7 | cabo san lucas
# Processing Record 0 of Set 7 | aykhal
# Processing Record 0 of Set 7 | kunduz
# Processing Record 0 of Set 7 | borogontsy
# Processing Record 0 of Set 7 | morehead city
# Processing Record 0 of Set 7 | klyuchi
# Processing Record 0 of Set 7 | kudahuvadhoo
# Processing Record 0 of Set 7 | grandview
# Processing Record 0 of Set 7 | kayangel
# Processing Record 0 of Set 7 | otse
# Processing Record 0 of Set 7 | madison
# Processing Record 0 of Set 8 | borovsk
# Processing Record 0 of Set 8 | cadale
# Processing Record 0 of Set 8 | vohipaho
# Processing Record 0 of Set 8 | impfondo
# Processing Record 0 of Set 8 | pasuquin
# Processing Record 0 of Set 9 | churapcha
# Processing Record 0 of Set 9 | chandler
# Processing Record 0 of Set 9 | stiens
# Processing Record 0 of Set 9 | kainantu
# Processing Record 0 of Set 9 | san sebastian de la gomera
# Processing Record 0 of Set 9 | pankrushikha
# Processing Record 0 of Set 9 | pahrump
# Processing Record 0 of Set 9 | nabire
# Processing Record 0 of Set 9 | sawang wirawong
# Processing Record 0 of Set 9 | arnedo
# Processing Record 0 of Set 9 | yemva
# Processing Record 0 of Set 9 | tomatlan
# Processing Record 0 of Set 9 | bebedja
# Processing Record 0 of Set 9 | piacabucu
# Processing Record 0 of Set 9 | newcastle
# Processing Record 0 of Set 9 | vilyeyka
# Processing Record 0 of Set 9 | buka
# Processing Record 0 of Set 9 | trosa
# Processing Record 0 of Set 9 | la ronge
# Processing Record 0 of Set 9 | sos'va
# Processing Record 0 of Set 9 | petropavlovka
# Processing Record 0 of Set 9 | chapada dos guimaraes
# Processing Record 0 of Set 9 | pakxan
# Processing Record 0 of Set 9 | sivrice
# Processing Record 0 of Set 9 | peace river
# Processing Record 0 of Set 10 | 'ohonua
# Processing Record 0 of Set 10 | horqueta
# Processing Record 0 of Set 10 | mathba
# Processing Record 0 of Set 10 | minas de marcona
# Processing Record 0 of Set 10 | chernyshevsk
# Processing Record 0 of Set 10 | mata-utu
# Processing Record 0 of Set 10 | almeirim
# Processing Record 0 of Set 10 | puerto san jose
# Processing Record 0 of Set 10 | ahvaz
# Processing Record 0 of Set 10 | wotho
# Processing Record 0 of Set 10 | tlaltenango de sanchez roman
# Processing Record 0 of Set 10 | queenstown
# Processing Record 0 of Set 10 | hoshiarpur
# Processing Record 0 of Set 10 | al fuwayliq
# Processing Record 0 of Set 10 | victorica
# Processing Record 0 of Set 10 | perevolotskiy
# Processing Record 0 of Set 10 | smithers
# Processing Record 0 of Set 10 | aljezur
# Processing Record 0 of Set 10 | flying fish cove
# Processing Record 0 of Set 10 | shimoda
# Processing Record 0 of Set 10 | igarka
# Processing Record 0 of Set 10 | cidade velha
# Processing Record 0 of Set 10 | myeik
# Processing Record 0 of Set 10 | cable beach
# Processing Record 0 of Set 10 | yuzhno-kurilsk
# Processing Record 0 of Set 10 | saint-georges
# Processing Record 0 of Set 10 | antofagasta
# Processing Record 0 of Set 10 | gadzhiyevo
# Processing Record 0 of Set 10 | basco
# Processing Record 0 of Set 10 | mount pleasant
# Processing Record 0 of Set 10 | tinana
# Processing Record 0 of Set 10 | kourou
# Processing Record 0 of Set 10 | weiser
# Processing Record 0 of Set 10 | saksaul'skiy
# Processing Record 0 of Set 10 | tchintabaraden
# Processing Record 0 of Set 10 | keelung
# Processing Record 0 of Set 10 | mili
# Processing Record 0 of Set 10 | khash
# Processing Record 0 of Set 10 | pampa
# Processing Record 0 of Set 10 | el granada
# Processing Record 0 of Set 10 | xaltianguis
# Processing Record 0 of Set 10 | mando
# Processing Record 0 of Set 10 | khanpur mahar
# Processing Record 0 of Set 10 | halifax
# Processing Record 0 of Set 10 | aliganj
# Processing Record 0 of Set 10 | usta muhammad
# Processing Record 0 of Set 10 | ribeirao branco
# Processing Record 0 of Set 10 | antonio enes
# Processing Record 0 of Set 10 | saint marys
# Processing Record 0 of Set 10 | camana
# Processing Record 0 of Set 11 | kovdor
# Processing Record 0 of Set 11 | laojunmiao
# Processing Record 0 of Set 11 | prince rupert
# Processing Record 0 of Set 11 | fauske
# Processing Record 0 of Set 11 | ha'il
# Processing Record 0 of Set 11 | bonnyville
# Processing Record 0 of Set 11 | tanggu
# Processing Record 0 of Set 11 | naberera
# Processing Record 0 of Set 11 | monte buey
# Processing Record 0 of Set 11 | kirakira
# Processing Record 0 of Set 11 | keflavik
# Processing Record 0 of Set 11 | ranau
# Processing Record 0 of Set 11 | togur
# Processing Record 0 of Set 11 | gaiman
# Processing Record 0 of Set 11 | chinde
# Processing Record 0 of Set 11 | crozet
# Processing Record 0 of Set 11 | severobaykal'sk
# Processing Record 0 of Set 11 | patterson
# Processing Record 0 of Set 11 | kamiiso
# Processing Record 0 of Set 11 | tongchuanshi
# Processing Record 0 of Set 11 | qarazhal
# Processing Record 0 of Set 11 | saint-mandrier-sur-mer
# Processing Record 0 of Set 11 | la passe
# Processing Record 0 of Set 11 | dzuunmod
# Processing Record 0 of Set 11 | belozersk
# Processing Record 0 of Set 11 | qarqaraly
# Processing Record 0 of Set 11 | taunsa
# Processing Record 0 of Set 11 | al jawf
# Processing Record 0 of Set 11 | carnarvon
# Processing Record 0 of Set 11 | nookat
# Processing Record 0 of Set 11 | undurkhaan
# Processing Record 0 of Set 11 | lorengau
# Processing Record 0 of Set 11 | namibe
# Processing Record 0 of Set 11 | hadibu
# Processing Record 0 of Set 11 | muisne
# Processing Record 0 of Set 11 | nyurba
# Processing Record 0 of Set 11 | lyubinskiy
# Processing Record 0 of Set 11 | katsuren-haebaru
# Processing Record 0 of Set 11 | okhotsk
# Processing Record 0 of Set 11 | ciudad tula
# Processing Record 0 of Set 11 | ytyk-kyuyel'
# Processing Record 0 of Set 11 | nemuro
# Processing Record 0 of Set 11 | nikolayevsk-on-amure
# Processing Record 0 of Set 11 | usogorsk
# Processing Record 0 of Set 11 | bedele
# Processing Record 0 of Set 11 | svencionys
# Processing Record 0 of Set 11 | northam
# Processing Record 0 of Set 11 | blackwater
# Processing Record 0 of Set 11 | vung tau
# Processing Record 0 of Set 11 | madalena
# Processing Record 0 of Set 12 | opuwo
# Processing Record 0 of Set 12 | inverell
# Processing Record 0 of Set 12 | tchaourou
# Processing Record 0 of Set 12 | touros
# Processing Record 0 of Set 12 | bereznik
# Processing Record 0 of Set 12 | margate
# Processing Record 0 of Set 12 | gobabis
# Processing Record 0 of Set 12 | miguel alves
# Processing Record 0 of Set 12 | banda aceh
# Processing Record 0 of Set 12 | yung shue wan
# Processing Record 0 of Set 12 | rexburg
# Processing Record 0 of Set 12 | viedma
# Processing Record 0 of Set 12 | puerto deseado
# Processing Record 0 of Set 12 | tshabong
# Processing Record 0 of Set 12 | mocimboa
# Processing Record 0 of Set 12 | mangai
# Processing Record 0 of Set 12 | ishigaki
# Processing Record 0 of Set 12 | lompoc
# Processing Record 0 of Set 12 | caleta de carquin
# Processing Record 0 of Set 12 | kalispell
# Processing Record 0 of Set 12 | hlukhiv
# Processing Record 0 of Set 12 | bad bruckenau
# Processing Record 0 of Set 12 | urengoy
# Processing Record 0 of Set 12 | tafuna
# Processing Record 0 of Set 12 | heroica caborca
# Processing Record 0 of Set 12 | sarkand
# Processing Record 0 of Set 12 | uman
# Processing Record 0 of Set 12 | santarem
# Processing Record 0 of Set 12 | mwene-ditu
# Processing Record 0 of Set 12 | aksuat
# Processing Record 0 of Set 12 | san julian
# Processing Record 0 of Set 12 | tsiolkovskiy
# Processing Record 0 of Set 12 | aroma
# Processing Record 0 of Set 12 | doda
# Processing Record 0 of Set 12 | kindu
# Processing Record 0 of Set 12 | mulayjah
# Processing Record 0 of Set 12 | kristinestad
# Processing Record 0 of Set 12 | ulladulla
# Processing Record 0 of Set 12 | machico
# Processing Record 0 of Set 12 | cill airne
# Processing Record 0 of Set 12 | titay
# Processing Record 0 of Set 12 | nishifukuma
# Processing Record 0 of Set 12 | pamandzi
# Processing Record 0 of Set 12 | akureyri
# Processing Record 0 of Set 12 | changli
# Processing Record 0 of Set 12 | alta
# Processing Record 0 of Set 12 | aitape
# Processing Record 0 of Set 12 | agbabu
# Processing Record 0 of Set 12 | lobujya
# Processing Record 0 of Set 12 | the pas
# Processing Record 0 of Set 13 | les anglais
# Processing Record 0 of Set 13 | glucholazy
# Processing Record 0 of Set 13 | point pedro
# Processing Record 0 of Set 13 | paradip garh
# Processing Record 0 of Set 13 | kittila
# Processing Record 0 of Set 13 | kirovo-chepetsk
# Processing Record 0 of Set 13 | pitkyaranta

# %%
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=839ebbda17f5f6b900db16b627d668a8&q=pitkyaranta'

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 31.4792, 'lat': 61.5734},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 258.99,
#   'feels_like': 252.59,
#   'temp_min': 258.99,
#   'temp_max': 258.99,
#   'pressure': 1002,
#   'humidity': 97,
#   'sea_level': 1002,
#   'grnd_level': 995},
#  'visibility': 10000,
#  'wind': {'speed': 3.04, 'deg': 74, 'gust': 4.34},
#  'clouds': {'all': 91},
#  'dt': 1700943400,
#  'sys': {'type': 2,
#   'id': 2088609,
#   'country': 'RU',
#   'sunrise': 1700893657,
#   'sunset': 1700916876},
#  'timezone': 10800,
#  'id': 509234,
#  'name': 'Pitkyaranta',
#  'cod': 200}

# %%
city_lat = city_weather["coord"]["lat"]
city_lat
# Out:
# 61.5734

# %%
city_cloud = city_weather["clouds"]
city_cloud
# Out:
# {'all': 91}

# %%
city_wind = city_weather["wind"]["speed"]
city_wind
# Out:
# 3.04

# %%
city_country = city_weather["sys"]["country"]
city_country
# Out:
# 'RU'

# %%
city_date = city_weather["dt"]
city_date
# Out:
# 1700943400
